# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Path to the CSV file
# Adjust path if necessary. Assuming we are in projects/osm-to-road-network/notebooks
# and the file is in projects/osm_to_road_network/output
CSV_PATH = "../data/output/Burnaby_driving_edge_graph.csv"

print(f"Loading {CSV_PATH}...")
df = pd.read_csv(CSV_PATH)
print(f"Loaded {len(df):,} rows.")
df.head()
# Out:
# Loading ../data/output/Burnaby_driving_edge_graph.csv...
# Loaded 98,901 rows.
#    incoming_edge  outgoing_edge
# 0          30721          30720
# 1          20799           1302
# 2           8066           8061
# 3          15745          15742
# 4          23542          23545

# %%
print("Building Graph...")
G = nx.DiGraph()

# The CSV contains pairs of edges: incoming_edge -> outgoing_edge
# We treat each 'edge' string as a node in our connectivity graph.
edges = df[['incoming_edge', 'outgoing_edge']].values
G.add_edges_from(edges)

print(f"Graph built: {G.number_of_nodes():,} nodes, {G.number_of_edges():,} edges")
# Out:
# Building Graph...
# Graph built: 34,965 nodes, 98,901 edges

# %%
print("Analyzing Connectivity...")

# Weakly Connected Components
wcc = list(nx.weakly_connected_components(G))
wcc_sizes = sorted([len(c) for c in wcc], reverse=True)

print(f"Number of Weakly Connected Components: {len(wcc):,}")
if wcc_sizes:
    print(f"Size of largest WCC: {wcc_sizes[0]:,}")
    print(f"Top 10 WCC sizes: {wcc_sizes[:10]}")

# Strongly Connected Components
scc = list(nx.strongly_connected_components(G))
scc_sizes = sorted([len(c) for c in scc], reverse=True)

print(f"Number of Strongly Connected Components: {len(scc):,}")
if scc_sizes:
    print(f"Size of largest SCC: {scc_sizes[0]:,}")
    print(f"Top 10 SCC sizes: {scc_sizes[:10]}")
# Out:
# Analyzing Connectivity...
# Number of Weakly Connected Components: 2
# Size of largest WCC: 34,925
# Top 10 WCC sizes: [34925, 40]
# Number of Strongly Connected Components: 2
# Size of largest SCC: 34,925
# Top 10 SCC sizes: [34925, 40]

# %% [markdown]
# # original graph

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Path to the CSV file
# Adjust path if necessary. Assuming we are in projects/osm-to-road-network/notebooks
# and the file is in projects/osm_to_road_network/output
CSV_PATH = "../data/output/Burnaby_driving_edges_indexed.csv"

print(f"Loading {CSV_PATH}...")
df = pd.read_csv(CSV_PATH)
print(f"Loaded {len(df):,} rows.")
df.head()
# Out:
# Loading ../data/output/Burnaby_driving_edges_indexed.csv...
# Loaded 34,965 rows.
#    edge_index   length  maxspeed  \
# 0           0   98.503      30.0
# 1           1   53.933      30.0
# 2           2  684.050      50.0
# 3           3   35.488      30.0
# 4           4   53.933      30.0
#
#                                             geometry        highway      cost  \
# 0  LINESTRING (-122.92154693603516 49.27764129638...  tertiary_link  11.82036
# 1  LINESTRING (-122.92154693603516 49.27764129638...       tertiary   6.47196
# 2  LINESTRING (-122.92154693603516 49.27764129638...       tertiary  49.25160
# 3  LINESTRING (-122.92096710205078 49.27793121337...       tertiary   4.25856
# 4  LINESTRING (-122.92096710205078 49.27793121337...       tertiary   6.47196
#
#         incoming_cell       outgoing_cell  lca_res  id
# 0  644733695069033029  644733695069283890        8   0
# 1  644733695069345412  644733695069283890        9   1
# 2  644733695063774494  644733695069283890        7   2
# 3  644733695069337920  644733695069345412       10   3
# 4  644733695069283890  644733695069345412        9   4

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Path to the boundary file
#boundary_path = "../data/output/Burnaby_driving_boundary.geojson"
#boundary_path = "../data/output/Somerset_driving_boundary.geojson"
#boundary_path = "../data/output/Vancouver_driving_boundary.geojson"
boundary_path = "../data/output/all_Vancouver_driving_boundary.geojson"

print(f"Loading boundary from {boundary_path}...")
boundary_gdf = gpd.read_file(boundary_path)

print("Plotting boundary...")
# Explore gives an interactive map
boundary_gdf.explore()
# Out:
# Loading boundary from ../data/output/all_Vancouver_driving_boundary.geojson...
# Plotting boundary...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfaf00315204c37702817dd4e3a28a5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfaf00315204c37702817dd4e3a28a5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfaf00315204c37702817dd4e3a28a5c = L.map(
#                 &quot;map_cfaf00315204c37702817dd4e3a28a5c&quot;,
#                 {
#                     center: [49.20810890197754, -122.90789031982422],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_cfaf00315204c37702817dd4e3a28a5c);
#
#
#
#
#
#             var tile_layer_71841e32dbb8aee4cbe69a64df9ad913 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71841e32dbb8aee4cbe69a64df9ad913.addTo(map_cfaf00315204c37702817dd4e3a28a5c);
#
#
#             map_cfaf00315204c37702817dd4e3a28a5c.fitBounds(
#                 [[48.98423385620117, -123.29228210449219], [49.431983947753906, -122.52349853515625]],
#                 {}
#             );
#
#
#         function geo_json_5fa1411ab480a88566984a73ec890603_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5fa1411ab480a88566984a73ec890603_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5fa1411ab480a88566984a73ec890603_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5fa1411ab480a88566984a73ec890603_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5fa1411ab480a88566984a73ec890603_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5fa1411ab480a88566984a73ec890603.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5fa1411ab480a88566984a73ec890603_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5fa1411ab480a88566984a73ec890603 = L.geoJson(null, {
#                 onEachFeature: geo_json_5fa1411ab480a88566984a73ec890603_onEachFeature,
#
#                 style: geo_json_5fa1411ab480a88566984a73ec890603_styler,
#                 pointToLayer: geo_json_5fa1411ab480a88566984a73ec890603_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5fa1411ab480a88566984a73ec890603_add (data) {
#             geo_json_5fa1411ab480a88566984a73ec890603
#                 .addData(data);
#         }
#             geo_json_5fa1411ab480a88566984a73ec890603_add({&quot;bbox&quot;: [-123.29228210449219, 48.98423385620117, -122.52349853515625, 49.431983947753906], &quot;features&quot;: [{&quot;bbox&quot;: [-123.29228210449219, 48.98423385620117, -122.52349853515625, 49.431983947753906], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-123.08216094970703, 48.98423385620117], [-123.16798400878906, 49.01095962524414], [-123.1717300415039, 49.01814270019531], [-123.26183319091797, 49.26627731
